# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage import exposure

img = io.imread("./histogram/ex1.jpg")
hist,bins = exposure.histogram(img,nbins=8)

plt.fill(bins,hist)
